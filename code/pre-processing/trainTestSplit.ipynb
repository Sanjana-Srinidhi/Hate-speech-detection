# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
df = pd.read_csv('/content/drive/MyDrive/MI/data/toxigen.csv')
df.head()
# Out:
#                                                 text  target_group  \
# 0  b'asians are trying to take over the world wit...         asian
# 1  b'i have never seen a hotter lineup in my life...       mexican
# 2                           b'muslims deseve to die'        muslim
# 3  b'people who are deaf or hard of hearing shoul...  physical_dis
# 4  b"Jews were all bad people because they're in ...        jewish
#
#                       factual?                 ingroup_effect  \
# 0                      opinion  doesn't use in-group language
# 1  neither factual nor opinion  doesn't use in-group language
# 2  neither factual nor opinion  doesn't use in-group language
# 3                      opinion  doesn't use in-group language
# 4                 disagreement  doesn't use in-group language
#
#                            lewd       framing  \
# 0  doesn't contain lewd content  disagreement
# 1  doesn't contain lewd content           NaN
# 2  doesn't contain lewd content         moral
# 3  doesn't contain lewd content  disagreement
# 4  doesn't contain lewd content         moral
#
#                                      predicted_group  \
# 0                 the text directly references asian
# 1  ['it is unclear who is referenced', 'it is unc...
# 2                the text directly references muslim
# 3  ['the text indirectly references physical_dis'...
# 4                the text directly references jewish
#
#                         stereotyping  intent  toxicity_ai  toxicity_human  \
# 0         uses positive stereotyping     5.0          5.0             5.0
# 1  doesn't use positive stereotyping     1.0          1.0             1.0
# 2  doesn't use positive stereotyping     5.0          5.0             5.0
# 3  doesn't use positive stereotyping     1.0          1.0             1.0
# 4  doesn't use positive stereotyping     5.0          5.0             5.0
#
#   predicted_author    label actual_method
# 0            human     hate          TopK
# 1            human  neutral          TopK
# 2            human     hate          TopK
# 3            human  neutral           CBS
# 4            human     hate          TopK

# %%
df['label'].value_counts()
# Out:
# neutral    4498
# hate       4462
# Name: label, dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder()
df['label']= label_encoder.fit_transform(df['label'])
df['label'].value_counts()
# Out:
# 1    4498
# 0    4462
# Name: label, dtype: int64

# %%
df_train, df_test = train_test_split(df, test_size = 0.2, random_state = 42)

# %%
df_train.head()
# Out:
#                                                    text  target_group  \
# 7632  b"when im telling people how much i have in my...        latino
# 2748  b"Anwar al-Awlaki (June 4, 1971  September 30,...        muslim
# 2812  b'all black people are suspected of trying to ...         asian
# 6008  b'every asian feels the need to own a camera a...         asian
# 6221  b'people who are blind or have low vision shou...  physical_dis
#
#                          factual?                 ingroup_effect  \
# 7632  neither factual nor opinion  doesn't use in-group language
# 2748  neither factual nor opinion  doesn't use in-group language
# 2812  neither factual nor opinion  doesn't use in-group language
# 6008  neither factual nor opinion  doesn't use in-group language
# 6221                 disagreement  doesn't use in-group language
#
#                               lewd       framing  \
# 7632  doesn't contain lewd content           NaN
# 2748  doesn't contain lewd content  disagreement
# 2812  doesn't contain lewd content         moral
# 6008  doesn't contain lewd content  disagreement
# 6221  doesn't contain lewd content  disagreement
#
#                                         predicted_group  \
# 7632                    it is unclear who is referenced
# 2748                    it is unclear who is referenced
# 2812  ['the text references black people', 'the text...
# 6008                 the text directly references asian
# 6221          the text directly references physical_dis
#
#                            stereotyping    intent  toxicity_ai  \
# 7632  doesn't use positive stereotyping  1.000000     1.000000
# 2748  doesn't use positive stereotyping  1.000000     1.000000
# 2812  doesn't use positive stereotyping  3.666667     4.333333
# 6008  doesn't use positive stereotyping  2.666667     3.000000
# 6221  doesn't use positive stereotyping  1.000000     1.000000
#
#       toxicity_human predicted_author  label actual_method
# 7632        1.000000            human      1          TopK
# 2748        1.000000            human      0          TopK
# 2812        4.666667            human      0          TopK
# 6008        3.000000            human      0          TopK
# 6221        1.000000            human      1           CBS

# %%
df_test.head()
# Out:
#                                                    text target_group  \
# 1962  b'we should be proud of our heritage, but we s...        asian
# 6596  b"all women are beautiful, even those that don...        women
# 653   b'i have a sister who is a doctor and a brothe...        women
# 7238  b'every other undesirable quality associated w...        black
# 7074  b'she does not have the same physical strength...        women
#
#                          factual?                 ingroup_effect  \
# 1962                      opinion  doesn't use in-group language
# 6596  neither factual nor opinion  doesn't use in-group language
# 653   neither factual nor opinion  doesn't use in-group language
# 7238  neither factual nor opinion  doesn't use in-group language
# 7074  neither factual nor opinion  doesn't use in-group language
#
#                               lewd       framing  \
# 1962  doesn't contain lewd content         moral
# 6596  doesn't contain lewd content  disagreement
# 653   doesn't contain lewd content  disagreement
# 7238  doesn't contain lewd content         moral
# 7074  doesn't contain lewd content         cause
#
#                                         predicted_group  \
# 1962                    it is unclear who is referenced
# 6596                 the text directly references women
# 653                     it is unclear who is referenced
# 7238                 the text directly references black
# 7074  ['it is unclear who is referenced', 'the text ...
#
#                            stereotyping    intent  toxicity_ai  \
# 1962  doesn't use positive stereotyping  2.000000     2.000000
# 6596                       disagreement  1.000000     1.333333
# 653   doesn't use positive stereotyping  1.000000     1.000000
# 7238  doesn't use positive stereotyping  4.000000     4.333333
# 7074  doesn't use positive stereotyping  2.666667     3.000000
#
#       toxicity_human predicted_author  label actual_method
# 1962        2.000000            human      1           CBS
# 6596        1.333333            human      1          TopK
# 653         1.000000            human      1           CBS
# 7238        4.333333            human      0          TopK
# 7074        3.333333               ai      0          TopK

# %%
print(len(df_train))
print(len(df_test))
# Out:
# 7168
# 1792

# %%
df_train.to_csv('/content/drive/MyDrive/MI/data/train_raw.csv', index = False)
df_test.to_csv('/content/drive/MyDrive/MI/data/test.csv', index = False)
